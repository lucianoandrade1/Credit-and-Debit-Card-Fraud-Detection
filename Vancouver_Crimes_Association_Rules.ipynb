# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
crimes=pd.read_csv("data/crimedata_csv_AllNeighbourhoods_AllYears.csv")
crimes.head()
# Out:
#                          TYPE  YEAR  MONTH  DAY  HOUR  MINUTE  \
# 0  Break and Enter Commercial  2012     12   14     8      52
# 1  Break and Enter Commercial  2019      3    7     2       6
# 2  Break and Enter Commercial  2019      8   27     4      12
# 3  Break and Enter Commercial  2021      4   26     4      44
# 4  Break and Enter Commercial  2014      8    8     5      13
#
#      HUNDRED_BLOCK NEIGHBOURHOOD            X             Y
# 0              NaN      Oakridge  491285.0000  5.453433e+06
# 1    10XX SITKA SQ      Fairview  490612.9648  5.457110e+06
# 2  10XX ALBERNI ST      West End  491004.8164  5.459177e+06
# 3  10XX ALBERNI ST      West End  491007.7798  5.459174e+06
# 4  10XX ALBERNI ST      West End  491015.9434  5.459166e+06

# %%
from shapely.geometry import Point
import geopandas as gpd
from geopandas import GeoDataFrame
import geodatasets

chicago = gpd.read_file(geodatasets.get_path("geoda.Vancouver_commpop"))
#geometry = [Point(xy) for xy in zip(mosquito['Lon'], mosquito['Lat'])]
#crs = {'init':'epsg:4326'}
#geo_df = gpd.GeoDataFrame(mosquito,
#                          crs=crs,
#                          geometry=geometry)

fig, ax = plt.subplots(figsize=(10,10))
chicago.plot(ax=ax, alpha=0.4, color='grey').set(title='CHICAGO')

#geo_df[geo_df['WNV Present'] == "negative"].plot(ax=ax, 
#                                       markersize=20, 
#                                       color='blue', 
#                                       marker='o', 
#                                       label='Negative')
#geo_df[geo_df['WNV Present'] == "positive"].plot(ax=ax, 
#                                       markersize=20, 
#                                       color='red', 
#                                       marker='^', 
#                                       label='Positive')
plt.legend(prop={'size':15})
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 6
#       3 from geopandas import GeoDataFrame
#       4 import geodatasets
# ----> 6 chicago = gpd.read_file(geodatasets.get_path("geoda.Vancouver_commpop"))
#       7 #geometry = [Point(xy) for xy in zip(mosquito['Lon'], mosquito['Lat'])]
#       8 #crs = {'init':'epsg:4326'}
#       9 #geo_df = gpd.GeoDataFrame(mosquito,
#      10 #                          crs=crs,
#      11 #                          geometry=geometry)
#      13 fig, ax = plt.subplots(figsize=(10,10))
#
# File ~\miniconda3\lib\site-packages\geodatasets\api.py:86, in get_path(name)
#      49 def get_path(name):
#      50     """Get the absolute path to a file in the local storage.
#      51
#      52     If it’s not in the local storage, it will be downloaded.
#    (...)
#      84     '/Users/martin/Library/Caches/geodatasets/airbnb.zip'
# ...
